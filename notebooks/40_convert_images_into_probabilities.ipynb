# %% [markdown]
# # Notebook Initialization

# %%
# %load nb_init.py

from pathlib import Path
import pandas as pd

base_dir = Path.cwd().parent
config_dir = base_dir / "config"
data_dir = base_dir / "data"
docs_dir = base_dir / "docs"
figures_dir = docs_dir / "figures"
models_dir = base_dir / "models"
logs_dir = base_dir / "logs"
images_input_dir = data_dir / "COVID19"
preprocessed_dir = data_dir / "preprocessed"
output_dir = data_dir / "output"

# Directories used to train the CNN (image by image) 
cnn_data_dir = data_dir / "modelling" / "cnn"
cnn_train_dir = cnn_data_dir / "train"
cnn_test_dir = cnn_data_dir / "test"

metadata_file = images_input_dir / "metadata.csv"
labels_file = images_input_dir / "unzip_filenames.csv"
preprocessed_labels_file = preprocessed_dir / "labels.parquet"

feature_extractor_model_file = models_dir / "feature_extractor.tf"

from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.getOrCreate()

config_file = config_dir / "tfg.conf"

from pyhocon import ConfigFactory
config = None

def load_config():
    return ConfigFactory.parse_file(config_file)

config = load_config()
    
import sys

if str(base_dir / "src") not in sys.path:
    sys.path.append(str(base_dir / "src"))

# %load_ext autoreload

# %autoreload 2

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.235:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from tfg import DataRepository

repo = DataRepository(config=config, base_data_path=data_dir)

# %% [markdown]
# # Load model

# %%
from tensorflow.keras.models import load_model
cnn_model_suffix = "06"
model_file = models_dir / f"feature_extractor_{cnn_model_suffix}.tf"
model = load_model(str(model_file))

model.summary()
# Out:
# Model: "covid_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_images (InputLayer)    [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_01 (Conv2D)           (None, 128, 128, 6)       168
# _________________________________________________________________
# maxpool2d_01 (MaxPooling2D)  (None, 64, 64, 6)         0
# _________________________________________________________________
# conv2d_02 (Conv2D)           (None, 64, 64, 12)        660
# _________________________________________________________________
# maxpool2d_02 (MaxPooling2D)  (None, 32, 32, 12)        0
# _________________________________________________________________
# conv2d_03 (Conv2D)           (None, 32, 32, 24)        2616
# _________________________________________________________________
# maxpool2d_03 (MaxPooling2D)  (None, 16, 16, 24)        0
# _________________________________________________________________
# conv2d_04 (Conv2D)           (None, 16, 16, 48)        10416
# _________________________________________________________________
# maxpool2d_04 (MaxPooling2D)  (None, 8, 8, 48)          0
# _________________________________________________________________
# conv2d_05 (Conv2D)           (None, 8, 8, 96)          41568
# _________________________________________________________________
# dropout__05 (Dropout)        (None, 8, 8, 96)          0
# _________________________________________________________________
# maxpool2d_05 (MaxPooling2D)  (None, 4, 4, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1536)              0
# _________________________________________________________________
# dense_01 (Dense)             (None, 64)                98368
# _________________________________________________________________
# dropout_01 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_02 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_02 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 3)                 99
# =================================================================
# Total params: 155,975
# Trainable params: 155,975
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Load datasets

# %%
train_df = repo.load("train_df")
train_df.head(5)
# Out:
#   label                   file  patient_id  scan_id  n_slice  num_clips  \
# 0   NCP  NCP/880/2415/0000.jpg         880     2415      312          5
# 1   NCP  NCP/880/2415/0001.jpg         880     2415      312          5
# 2   NCP  NCP/880/2415/0002.jpg         880     2415      312          5
# 3   NCP  NCP/880/2415/0003.jpg         880     2415      312          5
# 4   NCP  NCP/880/2415/0004.jpg         880     2415      312          5
#
#    seq_num  clip_num
# 0        0         0
# 1        1         0
# 2        2         0
# 3        3         0
# 4        4         0

# %% [markdown]
# It seems like the num_clips, seq_num and clip_num are not correct, we'll fix them..

# %%
from pyspark.sql import Window

images_per_clip = config.get_int("tfg.training.images_per_clip")

scan_window = Window\
    .partitionBy("patient_id", "scan_id")\
    .orderBy("file")

# %%
def fix_df(pandas_df):
    df = spark.createDataFrame(pandas_df)

    new_df = df\
        .withColumn("seq_num", F.row_number().over(scan_window) - 1)\
        .withColumn("num_clips", F.ceil(F.col("n_slice") / images_per_clip))\
        .withColumn("clip_num", F.floor(F.col("seq_num") / images_per_clip))\
        .toPandas()

    return new_df

# %%
train_df = repo.load("train_df")
train_df = fix_df(train_df)
repo.save("train_df", train_df)
train_df.head()
# Out:
#   label                   file  patient_id  scan_id  n_slice  num_clips  \
# 0   NCP  NCP/880/2415/0000.jpg         880     2415      312          5
# 1   NCP  NCP/880/2415/0001.jpg         880     2415      312          5
# 2   NCP  NCP/880/2415/0002.jpg         880     2415      312          5
# 3   NCP  NCP/880/2415/0003.jpg         880     2415      312          5
# 4   NCP  NCP/880/2415/0004.jpg         880     2415      312          5
#
#    seq_num  clip_num
# 0        0         0
# 1        1         0
# 2        2         0
# 3        3         0
# 4        4         0

# %%
val_df = repo.load("val_df")
val_df = fix_df(val_df)
repo.save("val_df", val_df)
val_df.head()

# %%
test_df = repo.load("test_df")
test_df = fix_df(test_df)
repo.save("test_df", test_df)
test_df.head()
# Out:
# True

# %% [markdown]
# # Convert images into features

# %%
img_size = config.get_int("tfg.training.img_size")
image_target_size = (img_size, img_size)
seed = config.get_int("tfg.seed")
batch_size = config.get_int("tfg.training.batch_size")

# %%
from keras_preprocessing.image import ImageDataGenerator

test_datagen = ImageDataGenerator(
    rescale=1./255.,
)

# %% [markdown]
# ## Train

# %%
train_df = repo.load("train_df")
train_generator = test_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=str(images_input_dir),
    x_col="file",
    y_col="label",
    batch_size=batch_size,
    seed=seed,
    shuffle=False,
    class_mode="categorical",
    target_size=image_target_size)
# Out:
# Found 331286 validated image filenames belonging to 3 classes.

# %%
train_generator.class_indices
# Out:
# {'CP': 0, 'NCP': 1, 'Normal': 2}

# %%
class_to_idx = train_generator.class_indices
idx_to_class = { v: k for k, v in class_to_idx.items() }

# %%
NUM_TRAIN_BATCHES = train_generator.n // train_generator.batch_size + 1

# %%
raw_train_feats = model.predict(train_generator, steps=NUM_TRAIN_BATCHES, verbose=1)
raw_train_feats.shape
# Out:
# 10/10 [==============================] - 1s 75ms/step
# (320, 3)

# %%
train_df["img_probs"] = raw_train_feats.tolist()
# Out:
# [[0.006345381494611502, 0.2938346266746521, 0.6998199820518494],
#  [0.003827716689556837, 0.3122704327106476, 0.683901846408844],
#  [0.005725017748773098, 0.38320884108543396, 0.6110661625862122],
#  [0.00022382025781553239, 0.29181888699531555, 0.7079572677612305],
#  [3.348174141137861e-05, 0.18306158483028412, 0.8169049024581909],
#  [0.00010949972056550905, 0.26848945021629333, 0.7314010262489319],
#  [4.633751086657867e-05, 0.19355522096157074, 0.8063984513282776],
#  [2.391957059444394e-05, 0.18498347699642181, 0.8149926066398621],
#  [1.1948675819439813e-05, 0.19143489003181458, 0.808553159236908],
#  [1.1003174194001986e-07, 0.10247980058193207, 0.897520124912262],
#  [1.0893384569499176e-05, 0.16673532128334045, 0.8332537412643433],
#  [3.7249768070068967e-07, 0.13027869164943695, 0.8697209358215332],
#  [4.7297056880779564e-05, 0.23403868079185486, 0.7659140825271606],
#  [6.372048915181949e-07, 0.13505439460277557, 0.8649449348449707],
#  [5.162765955901705e-05, 0.2951548099517822, 0.7047935724258423],
#  [1.4773697330383584e-05, 0.23159298300743103, 0.7683922648429871],
#  [7.998652290552855e-05, 0.22426611185073853, 0.7756538987159729],
#  [5.9956124459858984e-05, 0.30922365188598633, 0.6907163858413696],
#  [9.216415492119268e-06, 0.19276846945285797, 0.8072223663330078],
#  [5.081342806079192e-06, 0.1510722041130066, 0.8489227294921875],
#  [1.944523546626442e-07, 0.07966145873069763, 0.9203383326530457],
#  [3.152413663443099e-09, 0.05584772676229477, 0.944152295589447],
#  [1.9918347788916435e-06, 0.12405472248792648, 0.8759433627128601],
#  [6.305240276560653e-06, 0.16644631326198578, 0.8335473537445068],
#  [3.091610096817021e-07, 0.11232175678014755, 0.8876779675483704],
#  [1.1020483192680786e-08, 0.0770728588104248, 0.9229270815849304],
#  [3.6129958971287124e-06, 0.13069212436676025, 0.8693042993545532],
#  [6.127257165644551e-06, 0.15502269566059113, 0.8449711203575134],
#  [3.396692420665204e-07, 0.12129131704568863, 0.8787083029747009],
#  [3.835064266155541e-09, 0.0597907193005085, 0.9402092695236206],
#  [1.4139062143314618e-09, 0.054661136120557785, 0.9453388452529907],
#  [6.0446400311775506e-06, 0.10815849155187607, 0.8918354511260986],
#  [0.0001383474445901811, 0.21930618584156036, 0.7805554866790771],
#  [2.016191319853533e-05, 0.17091049253940582, 0.8290693163871765],
#  [0.0007159705273807049, 0.26705819368362427, 0.7322258949279785],
#  [0.00025465647922828794, 0.22900880873203278, 0.7707364559173584],
#  [0.0003799508267547935, 0.22979316115379333, 0.7698268890380859],
#  [4.618782259058207e-05, 0.16971616446971893, 0.830237627029419],
#  [4.882560460828245e-05, 0.20517931878566742, 0.7947718501091003],
#  [0.0006219239439815283, 0.22796836495399475, 0.7714096903800964],
#  [0.0011002379469573498, 0.30837973952293396, 0.6905199885368347],
#  [0.0006700744852423668, 0.21787908673286438, 0.7814508676528931],
#  [0.00026961840922012925, 0.21034617722034454, 0.7893842458724976],
#  [0.00026752802659757435, 0.23050051927566528, 0.769231915473938],
#  [0.0007275984389707446, 0.2868107259273529, 0.7124617099761963],
#  [0.00260355556383729, 0.27708640694618225, 0.7203100323677063],
#  [0.0015745083801448345, 0.23996680974960327, 0.75845867395401],
#  [0.0008563572773709893, 0.240158811211586, 0.7589848041534424],
#  [0.001511540962383151, 0.30553683638572693, 0.6929516196250916],
#  [0.0006258567445911467, 0.24087555706501007, 0.7584985494613647],
#  [1.5432617146871053e-05, 0.1650443822145462, 0.8349401950836182],
#  [0.009846724569797516, 0.4232841730117798, 0.5668690800666809],
#  [0.0026235028635710478, 0.3781239986419678, 0.6192524433135986],
#  [0.0027033959049731493, 0.35732463002204895, 0.6399719715118408],
#  [0.002762686228379607, 0.44715481996536255, 0.5500824451446533],
#  [0.0019901685882359743, 0.33379217982292175, 0.6642176508903503],
#  [0.004408608190715313, 0.5746157169342041, 0.4209756553173065],
#  [0.0013941670767962933, 0.28145161271095276, 0.7171542644500732],
#  [0.0002759674098342657, 0.21259178221225739, 0.787132203578949],
#  [0.0008102991268970072, 0.2265348732471466, 0.7726547718048096],
#  [0.0016291370848193765, 0.3482305705547333, 0.6501402854919434],
#  [0.0008747280808165669, 0.34237369894981384, 0.6567515730857849],
#  [0.002012989716604352, 0.3253912031650543, 0.6725957989692688],
#  [0.00041972455801442266, 0.2642349898815155, 0.7353453040122986],
#  [0.00019204424461349845, 0.26024410128593445, 0.7395638227462769],
#  [0.00023833313025534153, 0.321139931678772, 0.6786217093467712],
#  [2.2342806914821267e-05, 0.20622886717319489, 0.7937487959861755],
#  [6.0611393564613536e-05, 0.22100460529327393, 0.7789347767829895],
#  [4.1510647861287e-05, 0.19014008343219757, 0.8098184466362],
#  [0.00017712023691274226, 0.2656696140766144, 0.7341532111167908],
#  [0.00013636084622703493, 0.41306227445602417, 0.5868013501167297],
#  [0.0001140962413046509, 0.4234168529510498, 0.5764690637588501],
#  [0.0003549670218490064, 0.3071792423725128, 0.6924657821655273],
#  [0.0004227349709253758, 0.3132181465625763, 0.686359167098999],
#  [0.0007003478240221739, 0.366617888212204, 0.6326817274093628],
#  [0.000559101696126163, 0.43233829736709595, 0.5671025514602661],
#  [0.00011745734082069248, 0.34801962971687317, 0.6518629789352417],
#  [5.364121898310259e-05, 0.2550780773162842, 0.744868278503418],
#  [1.4570132407243364e-05, 0.18510907888412476, 0.81487637758255],
#  [1.3066139217698947e-05, 0.18834634125232697, 0.8116406202316284],
#  [1.6970521755865775e-05, 0.19188888370990753, 0.8080941438674927],
#  [0.00018236611504107714, 0.38343873620033264, 0.6163788437843323],
#  [6.0899801610503346e-05, 0.3772084712982178, 0.622730553150177],
#  [0.0003955810971092433, 0.33463385701179504, 0.6649705171585083],
#  [0.00046332209603860974, 0.5026969313621521, 0.496839702129364],
#  [0.0008258482557721436, 0.44754672050476074, 0.5516274571418762],
#  [1.1203732356079854e-05, 0.22235481441020966, 0.7776339650154114],
#  [6.737194780725986e-05, 0.46493807435035706, 0.5349945425987244],
#  [6.175093585625291e-05, 0.4771661162376404, 0.5227721333503723],
#  [0.00022685088333673775, 0.5287523865699768, 0.47102075815200806],
#  [8.304247603518888e-05, 0.5474350452423096, 0.4524819552898407],
#  [0.00021455904061440378, 0.623279869556427, 0.376505583524704],
#  [7.858659046178218e-06, 0.20691600441932678, 0.7930760979652405],
#  [0.00016812585818115622, 0.3762282729148865, 0.6236035823822021],
#  [1.9901301129721105e-05, 0.18612734973430634, 0.8138527274131775],
#  [4.212947146697843e-07, 0.1397036910057068, 0.860295832157135],
#  [2.2039304894860834e-05, 0.2713383734226227, 0.728639543056488],
#  [3.9918668335303664e-05, 0.43500298261642456, 0.5649570822715759],
#  [5.3829817261430435e-06, 0.3663926422595978, 0.63360196352005],
#  [3.0294746466097422e-05, 0.4945014417171478, 0.5054682493209839],
#  [6.159204349387437e-05, 0.8020296692848206, 0.19790875911712646],
#  [9.395503730047494e-05, 0.8748641610145569, 0.12504185736179352],
#  [0.00013127773127052933, 0.8403394818305969, 0.15952925384044647],
#  [0.00024207375827245414, 0.3861917555332184, 0.6135661602020264],
#  [0.002143287332728505, 0.8149094581604004, 0.18294721841812134],
#  [0.0011139208218082786, 0.9071841239929199, 0.09170205891132355],
#  [0.0001497067860327661, 0.8140366077423096, 0.18581366539001465],
#  [0.0011328523978590965, 0.8157035708427429, 0.1831635981798172],
#  [0.00043359448318369687, 0.7432692646980286, 0.25629711151123047],
#  [0.001132873585447669, 0.5998862385749817, 0.3989807963371277],
#  [0.0040361881256103516, 0.9179679751396179, 0.07799581438302994],
#  [0.0002298628824064508, 0.8962422609329224, 0.10352791100740433],
#  [0.001406367402523756, 0.5556896924972534, 0.44290396571159363],
#  [0.00017260195454582572, 0.8065202832221985, 0.1933070868253708],
#  [0.0013952064327895641, 0.7158112525939941, 0.2827935218811035],
#  [0.000545397459063679, 0.9248031973838806, 0.07465139776468277],
#  [0.0002603952307254076, 0.8628050088882446, 0.13693451881408691],
#  [0.00019801929011009634, 0.9022427201271057, 0.09755928069353104],
#  [0.00011358956544427201, 0.8925735354423523, 0.10731285065412521],
#  [0.00022446672664955258, 0.8767087459564209, 0.12306676805019379],
#  [5.309995322022587e-05, 0.8979751467704773, 0.10197175294160843],
#  [8.82116801221855e-05, 0.9619222283363342, 0.03798963129520416],
#  [6.498466245830059e-05, 0.933241069316864, 0.06669394671916962],
#  [0.00024025586026255041, 0.9558405876159668, 0.04391908645629883],
#  [0.0010989634320139885, 0.7944472432136536, 0.20445384085178375],
#  [0.0022367285564541817, 0.8171593546867371, 0.1806039959192276],
#  [0.011559994891285896, 0.7257405519485474, 0.2626994848251343],
#  [0.0010487352265045047, 0.7593435645103455, 0.23960761725902557],
#  [0.001761843916028738, 0.6501707434654236, 0.34806737303733826],
#  [0.0039629265666007996, 0.6970199942588806, 0.2990170121192932],
#  [0.0006303475238382816, 0.9670529365539551, 0.03231671079993248],
#  [0.0004368136287666857, 0.9697065949440002, 0.02985658310353756],
#  [0.000780151691287756, 0.9510958194732666, 0.048123978078365326],
#  [0.00028903651400469244, 0.9533823132514954, 0.04632868990302086],
#  [0.0009436501422896981, 0.787372887134552, 0.21168342232704163],
#  [0.0012436857214197516, 0.5126448273658752, 0.48611146211624146],
#  [0.0024442386347800493, 0.5893939137458801, 0.40816184878349304],
#  [0.0005042651318944991, 0.7223737239837646, 0.27712196111679077],
#  [0.0001965848496183753, 0.8635743260383606, 0.13622906804084778],
#  [5.3839779866393656e-05, 0.8945789337158203, 0.1053672507405281],
#  [0.0005011129542253911, 0.8552747964859009, 0.14422409236431122],
#  [0.0016483135987073183, 0.6242627501487732, 0.37408900260925293],
#  [0.0004251170321367681, 0.770354151725769, 0.22922074794769287],
#  [0.0009099366725422442, 0.8264679908752441, 0.17262205481529236],
#  [0.004595708567649126, 0.8068124055862427, 0.18859176337718964],
#  [0.0005876870127394795, 0.4400104284286499, 0.5594018697738647],
#  [0.0029514452908188105, 0.5809792876243591, 0.41606926918029785],
#  [0.0036699988413602114, 0.7280510067939758, 0.26827895641326904],
#  [2.2475012883660384e-05, 0.21950866281986237, 0.7804688811302185],
#  [0.00010124410619027913, 0.30360203981399536, 0.6962966918945312],
#  [0.0003559855977073312, 0.4011942148208618, 0.5984497666358948],
#  [0.00013480681809596717, 0.3304463326931, 0.6694188714027405],
#  [1.1770665878430009e-05, 0.2266360968351364, 0.7733521461486816],
#  [0.00012392157805152237, 0.3960312306880951, 0.6038448810577393],
#  [6.84882907080464e-05, 0.366421639919281, 0.6335098743438721],
#  [0.0006530415848828852, 0.8771464228630066, 0.1222006231546402],
#  [0.00014388847921509296, 0.3542446196079254, 0.6456114649772644],
#  [0.0009827278554439545, 0.6315144300460815, 0.3675028085708618],
#  [0.0006503043114207685, 0.45951277017593384, 0.5398369431495667],
#  [0.00019326398614794016, 0.38254716992378235, 0.6172595620155334],
#  [0.0011782646179199219, 0.7626498937606812, 0.23617184162139893],
#  [0.0017246182542294264, 0.827961266040802, 0.17031411826610565],
#  [0.0007650773623026907, 0.8834835886955261, 0.11575133353471756],
#  [0.0006955793942324817, 0.8279829025268555, 0.17132152616977692],
#  [0.00044370899558998644, 0.9379924535751343, 0.061563871800899506],
#  [8.761955541558564e-05, 0.5821789503097534, 0.41773346066474915],
#  [1.640788104850799e-05, 0.29307517409324646, 0.7069084048271179],
#  [0.00014036663924343884, 0.4652744233608246, 0.534585177898407],
#  [0.00010791562817757949, 0.8433430790901184, 0.15654903650283813],
#  [0.00014226888015400618, 0.7503495812416077, 0.2495080828666687],
#  [0.00034381423029117286, 0.5749533176422119, 0.42470285296440125],
#  [0.00047991800238378346, 0.8281764388084412, 0.17134368419647217],
#  [0.00018010316125582904, 0.8860995769500732, 0.1137203723192215],
#  [0.0001951974700205028, 0.48765766620635986, 0.5121471285820007],
#  [0.0002678940654732287, 0.8187171816825867, 0.18101489543914795],
#  [0.00024909147759899497, 0.8347993493080139, 0.1649516075849533],
#  [0.0009184873197227716, 0.9038187265396118, 0.09526278078556061],
#  [0.00014795463357586414, 0.3072458803653717, 0.6926062107086182],
#  [0.0014712386764585972, 0.3390980660915375, 0.659430742263794],
#  [0.006437657400965691, 0.7266056537628174, 0.2669566869735718],
#  [0.000912620103918016, 0.8990142941474915, 0.10007302463054657],
#  [0.014758680015802383, 0.7633081078529358, 0.2219332605600357],
#  [0.0076116095297038555, 0.7710207104682922, 0.2213677018880844],
#  [0.0040695625357329845, 0.6459760665893555, 0.34995436668395996],
#  [0.0011977580143138766, 0.417030930519104, 0.5817713141441345],
#  [0.0010072995210066438, 0.4397120475769043, 0.5592806339263916],
#  [0.0027123282197862864, 0.5650568604469299, 0.4322308301925659],
#  [0.00021544861374422908, 0.39280834794044495, 0.6069762110710144],
#  [0.0002499956462997943, 0.5991370677947998, 0.4006129801273346],
#  [0.0002712684217840433, 0.33064863085746765, 0.6690801382064819],
#  [0.002597284968942404, 0.43554073572158813, 0.5618619918823242],
#  [0.000846654933411628, 0.6543737649917603, 0.3447796106338501],
#  [1.3073923582851421e-05, 0.24349460005760193, 0.7564923167228699],
#  [0.0001027527468977496, 0.36790958046913147, 0.6319876313209534],
#  [4.7639568379054253e-07, 0.1194627434015274, 0.8805367946624756],
#  [1.4269663552113343e-05, 0.15474998950958252, 0.8452357649803162],
#  [4.339791104257529e-08, 0.08315528184175491, 0.9168446660041809],
#  [3.1209907319862396e-05, 0.18503248691558838, 0.8149362802505493],
#  [0.0004910632269456983, 0.3984566330909729, 0.6010522842407227],
#  [0.00032513024052605033, 0.2649928629398346, 0.734682023525238],
#  [0.006098147947341204, 0.4685055613517761, 0.5253962874412537],
#  [0.001780331484042108, 0.41741135716438293, 0.5808082818984985],
#  [0.004077487625181675, 0.38517826795578003, 0.610744297504425],
#  [0.010899742133915424, 0.6293337345123291, 0.35976657271385193],
#  [7.333546818699688e-05, 0.33717402815818787, 0.6627526879310608],
#  [0.005052725784480572, 0.6254953145980835, 0.3694518804550171],
#  [0.001379267661832273, 0.5040838122367859, 0.4945369064807892],
#  [0.00016439308819826692, 0.25868386030197144, 0.741151750087738],
#  [0.011290451511740685, 0.7379233241081238, 0.25078627467155457],
#  [0.0035223723389208317, 0.8390046954154968, 0.1574728786945343],
#  [0.0036507530603557825, 0.8971278071403503, 0.09922148287296295],
#  [0.012767484411597252, 0.8232372403144836, 0.16399522125720978],
#  [0.0002311664429726079, 0.27683594822883606, 0.7229328751564026],
#  [0.00059167091967538, 0.3117236793041229, 0.6876846551895142],
#  [0.000289102055830881, 0.3079923391342163, 0.691718578338623],
#  [0.0030087416525930166, 0.3509315252304077, 0.6460597515106201],
#  [0.005549679975956678, 0.8099398016929626, 0.18451052904129028],
#  [0.0027315199840813875, 0.9118810296058655, 0.08538738638162613],
#  [0.009191910736262798, 0.8490437865257263, 0.14176426827907562],
#  [0.009327822364866734, 0.8128717541694641, 0.17780038714408875],
#  [0.004184381105005741, 0.6698260307312012, 0.32598963379859924],
#  [0.0009643646772019565, 0.6720262765884399, 0.3270093500614166],
#  [0.0005981590365990996, 0.6110638976097107, 0.38833799958229065],
#  [0.002002656226977706, 0.837152361869812, 0.1608450710773468],
#  [0.0020302406046539545, 0.5850869417190552, 0.41288280487060547],
#  [0.017515501007437706, 0.6523082852363586, 0.3301762640476227],
#  [0.004962895531207323, 0.6693903207778931, 0.3256467282772064],
#  [0.0006132419221103191, 0.26941877603530884, 0.7299679517745972],
#  [0.0011266372166574001, 0.4054984152317047, 0.5933749675750732],
#  [0.007240965962409973, 0.4749962389469147, 0.5177627801895142],
#  [0.01477834489196539, 0.6386677026748657, 0.34655389189720154],
#  [0.002279777778312564, 0.4501170814037323, 0.547603189945221],
#  [0.0012148810783401132, 0.35213524103164673, 0.6466498374938965],
#  [0.001990083372220397, 0.4106440544128418, 0.5873658657073975],
#  [0.004391382448375225, 0.6756920218467712, 0.31991663575172424],
#  [0.0014926170697435737, 0.3591209352016449, 0.6393864154815674],
#  [0.003415945917367935, 0.767219603061676, 0.22936446964740753],
#  [0.0010569676524028182, 0.44262611865997314, 0.5563169121742249],
#  [0.001298403018154204, 0.7292705178260803, 0.26943111419677734],
#  [0.0004240713606122881, 0.29092979431152344, 0.7086461782455444],
#  [0.010092823766171932, 0.4524146020412445, 0.537492573261261],
#  [0.004037497565150261, 0.8717382550239563, 0.12422428280115128],
#  [0.003751629265025258, 0.8362627029418945, 0.15998560190200806],
#  [0.014974762685596943, 0.39238739013671875, 0.592637836933136],
#  [0.0009611803106963634, 0.2940346598625183, 0.7050042152404785],
#  [0.00417531980201602, 0.6042163968086243, 0.39160823822021484],
#  [0.009222377091646194, 0.42921268939971924, 0.5615649819374084],
#  [0.01021766196936369, 0.536841094493866, 0.4529412090778351],
#  [0.004233524668961763, 0.44623178243637085, 0.5495346784591675],
#  [0.01384707447141409, 0.540197491645813, 0.44595542550086975],
#  [0.007065379526466131, 0.7894699573516846, 0.20346462726593018],
#  [0.01174257230013609, 0.6478241682052612, 0.3404332995414734],
#  [0.011994967237114906, 0.6493801474571228, 0.33862489461898804],
#  [0.006461063865572214, 0.49910789728164673, 0.4944310188293457],
#  [0.011795438826084137, 0.6201558113098145, 0.36804884672164917],
#  [0.008527268655598164, 0.5628207325935364, 0.4286520481109619],
#  [0.004325267858803272, 0.3920793831348419, 0.6035953164100647],
#  [0.0026881746016442776, 0.5340009927749634, 0.4633108675479889],
#  [0.0023519820533692837, 0.59836745262146, 0.3992805480957031],
#  [0.009295063093304634, 0.7256847023963928, 0.2650202214717865],
#  [0.037828266620635986, 0.6695939302444458, 0.29257774353027344],
#  [0.007677110843360424, 0.7384586930274963, 0.25386419892311096],
#  [0.0022802045568823814, 0.5517074465751648, 0.44601234793663025],
#  [0.008197198621928692, 0.5398467779159546, 0.45195603370666504],
#  [0.0004972644383087754, 0.2747291922569275, 0.7247734665870667],
#  [0.0008852356113493443, 0.40032076835632324, 0.5987939834594727],
#  [0.00332307955250144, 0.7055264115333557, 0.2911505103111267],
#  [0.0010499152122065425, 0.5575053691864014, 0.4414446949958801],
#  [0.004296089988201857, 0.4877627193927765, 0.5079411864280701],
#  [0.006387912668287754, 0.6288272142410278, 0.3647848963737488],
#  [0.004642438143491745, 0.5561915040016174, 0.4391661286354065],
#  [0.020976239815354347, 0.635160505771637, 0.34386318922042847],
#  [0.008615469560027122, 0.4437456429004669, 0.5476388335227966],
#  [0.05528591200709343, 0.6369983553886414, 0.3077157437801361],
#  [0.04585685580968857, 0.6439948081970215, 0.31014832854270935],
#  [0.010305281728506088, 0.4688735008239746, 0.520821213722229],
#  [0.021219471469521523, 0.39409270882606506, 0.5846878290176392],
#  [0.005143654067069292, 0.31143718957901, 0.6834191679954529],
#  [0.013391331769526005, 0.5108204483985901, 0.4757882356643677],
#  [0.009342324919998646, 0.5131545662879944, 0.47750312089920044],
#  [0.004920194856822491, 0.35210278630256653, 0.6429769396781921],
#  [0.0059942202642560005, 0.327225923538208, 0.6667798757553101],
#  [0.0018996773287653923, 0.2693747878074646, 0.7287255525588989],
#  [0.0024943773169070482, 0.29312682151794434, 0.7043788433074951],
#  [0.006021884270012379, 0.41495826840400696, 0.5790198445320129],
#  [0.0278627946972847, 0.48077037930488586, 0.4913669228553772],
#  [0.038242630660533905, 0.5935186147689819, 0.3682387173175812],
#  [0.0474526584148407, 0.5078539848327637, 0.44469335675239563],
#  [0.0005846702260896564, 0.2109052687883377, 0.7885100841522217],
#  [0.0028610359877347946, 0.32237887382507324, 0.674760103225708],
#  [0.003723007394000888, 0.23445305228233337, 0.7618239521980286],
#  [0.0031021172180771828, 0.2512432634830475, 0.7456545829772949],
#  [0.003591259941458702, 0.2763471007347107, 0.7200616598129272],
#  [0.0020651782397180796, 0.34013864398002625, 0.6577961444854736],
#  [0.0054517085663974285, 0.45791396498680115, 0.5366343259811401],
#  [0.0005505923763848841, 0.25734812021255493, 0.7421013116836548],
#  [0.004693964961916208, 0.37675735354423523, 0.6185486912727356],
#  [2.5619629013817757e-05, 0.17462891340255737, 0.8253454566001892],
#  [0.00019000332395080477, 0.21291698515415192, 0.7868929505348206],
#  [0.0017700630705803633, 0.3901664912700653, 0.6080633997917175],
#  [0.0044169011525809765, 0.4176272451877594, 0.5779558420181274],
#  [0.0015368268359452486, 0.35116201639175415, 0.6473011374473572],
#  [0.000837551080621779, 0.33706507086753845, 0.6620973348617554],
#  [0.001926305703818798, 0.34082096815109253, 0.6572527885437012],
#  [0.0032059750519692898, 0.36916816234588623, 0.6276258230209351],
#  [0.0020885395351797342, 0.33711498975753784, 0.6607965230941772],
#  [0.0011593530653044581, 0.39354294538497925, 0.6052977442741394],
#  [0.00015159850590862334, 0.272438108921051, 0.7274103164672852],
#  [0.0006062589818611741, 0.2357773780822754, 0.7636163234710693],
#  [0.0002696763549465686, 0.2546771466732025, 0.7450531721115112],
#  [0.0028348180931061506, 0.38212916254997253, 0.6150360107421875],
#  [0.014539779163897038, 0.46573781967163086, 0.5197223424911499],
#  [0.6113688349723816, 0.0012682924279943109, 0.38736283779144287],
#  [0.6803227663040161, 0.0011680001625791192, 0.31850919127464294],
#  [0.6791799664497375, 0.002429942600429058, 0.3183901309967041],
#  [0.4779246151447296, 0.0021095590200275183, 0.5199658274650574],
#  [0.3237210810184479, 0.0011087814345955849, 0.6751701235771179],
#  [0.4100339412689209, 0.002763741184026003, 0.5872023105621338],
#  [0.5682424306869507, 0.004668307024985552, 0.42708930373191833],
#  [0.6494989395141602, 0.005826150067150593, 0.34467488527297974]]

# %%
repo.save("train_features", train_df)
# Out:
# True

# %%
train_feats = repo.load("train_features")
train_feats.head(5)
# Out:
#                     file label  patient_id  scan_id  n_slice  num_clips  \
# 0  NCP/880/2415/0000.jpg   NCP         880     2415      312          5
# 1  NCP/880/2415/0001.jpg   NCP         880     2415      312          5
# 2  NCP/880/2415/0002.jpg   NCP         880     2415      312          5
# 3  NCP/880/2415/0003.jpg   NCP         880     2415      312          5
# 4  NCP/880/2415/0004.jpg   NCP         880     2415      312          5
#
#    seq_num  clip_num                                       img_features
# 0        0         0  [0.0, 5.270750045776367, 0.0, 5.07415866851806...
# 1        1         0  [0.0, 2.8091320991516113, 0.0, 2.9504299163818...
# 2        2         0  [0.0, 3.616379737854004, 0.19390609860420227, ...
# 3        3         0  [0.0, 2.734466314315796, 0.0, 2.81957268714904...
# 4        4         0  [0.0, 9.06471061706543, 0.0, 7.898210525512695...

# %% [markdown]
# ## Validation

# %%
val_df = repo.load("val_df")

val_generator = test_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=str(images_input_dir),
    x_col="file",
    y_col="label",
    batch_size=batch_size,
    seed=seed,
    shuffle=False,
    class_mode="categorical",
    target_size=image_target_size)

NUM_VAL_BATCHES = val_generator.n // val_generator.batch_size + 1

raw_val_feats = new_model.predict(val_generator, steps=NUM_VAL_BATCHES, verbose=1)
raw_val_feats.shape
# Out:
# Found 39828 validated image filenames belonging to 3 classes.
# 1245/1245 [==============================] - 290s 233ms/step
# (39828, 32)

# %%
val_df["img_features"] = raw_val_feats.tolist()
val_df.head()
# Out:
#                     file                                       img_features
# 0  CP/1075/3118/0543.jpg  [0.5893998742103577, 0.0, 3.105539083480835, 0...
# 1  CP/1075/3118/0174.jpg  [2.171123504638672, 0.0, 5.15280818939209, 0.0...
# 2  CP/1075/3118/0130.jpg  [2.2265334129333496, 0.0, 6.776073455810547, 0...
# 3  CP/1075/3118/0525.jpg  [1.0836143493652344, 0.0, 3.375173330307007, 0...
# 4  CP/1075/3118/0152.jpg  [2.058112621307373, 0.0, 5.975271224975586, 0....

# %%
repo.save("val_features", val_df)
# Out:
# True

# %% [markdown]
# ## Test

# %%
test_df = repo.load("test_df")

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=str(images_input_dir),
    x_col="file",
    y_col="label",
    batch_size=batch_size,
    seed=seed,
    shuffle=False,
    class_mode="categorical",
    target_size=image_target_size)

NUM_TEST_BATCHES = test_generator.n // test_generator.batch_size + 1

raw_test_feats = new_model.predict(test_generator, steps=NUM_TEST_BATCHES, verbose=1)
raw_test_feats.shape
# Out:
# Found 40415 validated image filenames belonging to 3 classes.
# 1263/1263 [==============================] - 289s 228ms/step
# (40415, 32)

# %%
test_df["img_features"] = raw_test_feats.tolist()
repo.save("test_features", test_df)

test_feats = repo.load("test_features")
test_feats.head(5)
# Out:
#   label                file  patient_id  scan_id  n_slice  num_clips  seq_num  \
# 0    CP  CP/1/3143/0275.png           1     3143      300          1        0
# 1    CP  CP/1/3143/0064.png           1     3143      300          1        1
# 2    CP  CP/1/3143/0083.png           1     3143      300          1        2
# 3    CP  CP/1/3143/0160.png           1     3143      300          1        3
# 4    CP  CP/1/3143/0286.png           1     3143      300          1        4
#
#    clip_num                                       img_features
# 0         0  [0.5805813670158386, 0.0, 1.381737232208252, 0...
# 1         0  [0.4474046230316162, 0.0, 1.0005760192871094, ...
# 2         0  [0.157572939991951, 0.0, 1.0315451622009277, 0...
# 3         0  [0.4971274733543396, 0.0, 1.757103681564331, 0...
# 4         0  [0.0, 0.35277533531188965, 2.1408023834228516,...

# %% [markdown]
# # Group features into clips

# %%
def agg_features(series):
    series = sorted(series, key=lambda t: t[0])
    
    return [seq_feats[1] for seq_feats in series]

# %%
def make_clips(df):
    df["seq_features"] = list(zip(df.seq_num, df.img_features))
    df_clips = df\
        .groupby(by=["patient_id", "scan_id", "label", "n_slice", "clip_num"])\
        .agg({
            'file': ["min", "max"],
            'seq_features': [agg_features]
        })\
        .reset_index()

    # Takes care of the multi-index after the groupby
    df_clips.columns = df_clips.columns.map(lambda t: '_'.join(t).rstrip("_"))

    df_clips = df_clips.rename(columns={
        "seq_features_agg_features": "seq_features",
        "file_min": "clip_start_file",
        "file_max": "clip_end_file",
    })
    
    return df_clips

# %%
train_feats = repo.load("train_features")
train_clips = make_clips(train_feats)
train_clips.head()
# Out:
#    patient_id  scan_id label  n_slice  clip_num     clip_start_file  \
# 0           0     3131    CP      285         0  CP/0/3131/0000.png
# 1           0     3131    CP      285         1  CP/0/3131/0070.png
# 2           0     3131    CP      285         2  CP/0/3131/0140.png
# 3           0     3131    CP      285         3  CP/0/3131/0210.png
# 4           0     3131    CP      285         4  CP/0/3131/0280.png
#
#         clip_end_file                                       seq_features
# 0  CP/0/3131/0069.png  [[0.0, 0.0, 2.9882235527038574, 0.0, 0.0, 0.0,...
# 1  CP/0/3131/0139.png  [[0.0, 0.015588469803333282, 2.548190832138061...
# 2  CP/0/3131/0209.png  [[0.3391307592391968, 0.016530275344848633, 2....
# 3  CP/0/3131/0279.png  [[0.29484760761260986, 0.0, 1.7729129791259766...
# 4  CP/0/3131/0284.png  [[2.112011671066284, 0.0, 3.815093755722046, 0...

# %%
train_clips.shape
# Out:
# (6117, 8)

# %%
repo.save("train_clips", train_clips)
# Out:
# True

# %%
val_feats = repo.load("val_features")
val_clips = make_clips(val_feats)
val_clips.head()
# Out:
#    patient_id  scan_id label  n_slice  clip_num     clip_start_file  \
# 0           4     3505    CP      298         0  CP/4/3505/0000.png
# 1           4     3505    CP      298         1  CP/4/3505/0070.png
# 2           4     3505    CP      298         2  CP/4/3505/0140.png
# 3           4     3505    CP      298         3  CP/4/3505/0210.png
# 4           4     3505    CP      298         4  CP/4/3505/0280.png
#
#         clip_end_file                                       seq_features
# 0  CP/4/3505/0069.png  [[2.613647699356079, 0.0, 0.9890813827514648, ...
# 1  CP/4/3505/0139.png  [[3.2934000492095947, 0.0, 5.15690279006958, 0...
# 2  CP/4/3505/0209.png  [[3.833109140396118, 0.0, 5.286610126495361, 0...
# 3  CP/4/3505/0279.png  [[3.43273663520813, 0.0, 0.621675968170166, 0....
# 4  CP/4/3505/0297.png  [[4.024286270141602, 0.0, 1.0903337001800537, ...

# %%
val_clips.shape
# Out:
# (744, 8)

# %%
repo.save("val_clips", val_clips)
# Out:
# True

# %%
test_feats = repo.load("test_features")
test_clips = make_clips(test_feats)
test_clips.head()
# Out:
#    patient_id  scan_id label  n_slice  clip_num     clip_start_file  \
# 0           1     3143    CP      300         0  CP/1/3143/0000.png
# 1           1     3143    CP      300         1  CP/1/3143/0070.png
# 2           1     3143    CP      300         2  CP/1/3143/0140.png
# 3           1     3143    CP      300         3  CP/1/3143/0210.png
# 4           1     3143    CP      300         4  CP/1/3143/0280.png
#
#         clip_end_file                                       seq_features
# 0  CP/1/3143/0069.png  [[0.7901433110237122, 0.0, 0.4899705648422241,...
# 1  CP/1/3143/0139.png  [[0.39713576436042786, 0.0, 0.7319959402084351...
# 2  CP/1/3143/0209.png  [[0.655151903629303, 0.0, 1.253217101097107, 0...
# 3  CP/1/3143/0279.png  [[1.5254734754562378, 0.0, 3.0512397289276123,...
# 4  CP/1/3143/0299.png  [[0.0, 0.09542667120695114, 1.2658686637878418...

# %%
test_clips.shape
# Out:
# (752, 8)

# %%
repo.save("test_clips", test_clips)
# Out:
# True
